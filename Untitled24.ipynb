# %% [markdown]
# <a href="https://colab.research.google.com/github/amna-zaynab/Object-Detection---YOLOv8-Micro-Project-/blob/main/Untitled24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
from google.colab import files
files.upload()

# %%
import os
os.listdir()

# %%
import cv2
img=cv2.imread("apples.jpg")
print(img is None)

# %%
from ultralytics import YOLO
import time

model = YOLO("yolov8n.pt")

start = time.time()
results = model(img, conf=0.5)[0]

for box in results.boxes:
    x1, y1, x2, y2 = map(int, box.xyxy[0])
    label = model.names[int(box.cls[0])]

    cv2.rectangle(img, (x1,y1), (x2,y2), (180,0,255), 2)
    cv2.putText(img, label, (x1,y1-10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255,255,255), 2)

    cx, cy = (x1+x2)//2, (y1+y2)//2
    cv2.circle(img, (cx,cy), 4, (0,255,0), -1)
    cv2.line(img, (cx,cy), (cx, cy-40), (0,255,0), 2)

fps = 1 / (time.time() - start)
cv2.putText(
    img,
    label,
    (x1 + 5, y1 + 25),   # inside the box
    cv2.FONT_HERSHEY_SIMPLEX,
    0.8,
    (0, 0, 255),        # RED text
    2
)
cv2.imwrite("output_image.jpg", img)
print("✅ output_image.jpg saved")

# %%
from IPython.display import Image
display(Image("output_image.jpg"))
